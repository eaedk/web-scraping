# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
driver_options = Options()
driver_options.add_argument("accept-language=en-US")

s=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s,options=driver_options)
driver.maximize_window()

actions = ActionChains(driver)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\emman\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %%
INITIAL_WEBSITE = "https://www.jumia.sn/"
data = {}
# go to the root page and get header/menu with its sub-items

# %%
def process_article(article):
    """retrive needed information from an article"""
    try:
        name = article.find_element(by=By.CSS_SELECTOR, value='h3.name').text
        price = article.find_element(by=By.CSS_SELECTOR, value='div.prc').text
        img_link = article.find_element(by=By.CSS_SELECTOR, value='img.img').get_attribute('data-src')
        descrption_link = article.find_element(by=By.CSS_SELECTOR, value='a.core').get_attribute('href')
        try:
            old_price, decrease_percentage = article.find_element(by=By.CSS_SELECTOR, value='div.s-prc-w').text.split("\n")
        except:
            old_price, decrease_percentage = '', ''
        try:
            n_stars, n_votes = article.find_element(by=By.CSS_SELECTOR, value='div.rev').text.split("\n")
            # n_votes = int(n_votes.replace("(", "").replace(")", "")) # clean value and convert to int 
        except:
            n_stars, n_votes = '', ''
        try:
            article.find_element(by=By.CSS_SELECTOR, value='svg.ic.xprss')
            jumia_express = True
        except:
            jumia_express = False

        article_data = dict(name=name , price=price , descrption_link=descrption_link , img_link=img_link , jumia_express=jumia_express ,
                       old_price=old_price , decrease_percentage=decrease_percentage ,n_stars=n_stars, n_votes=n_votes  )
    except:
        article_data = None
    return article_data

# %%
def close_popup(driver):
    """close pop up frames"""
    try:
        [btn.click() for btn in driver.find_elements(by=By.CSS_SELECTOR, value='button.cls')]
    except:
        pass

# %%
driver.get(INITIAL_WEBSITE)
close_popup(driver)

pages = []
categories = driver.find_elements(by=By.CSS_SELECTOR, value='div.flyout-w > div > a.itm')
for (i,category) in enumerate(categories):
    actions.move_to_element(category).perform()
    sub_menu = driver.find_elements(by=By.CSS_SELECTOR, value='div.flyout-w > div > div.sub')[i]
    sub_menu_groups = sub_menu.find_elements(by=By.CSS_SELECTOR, value='div > div > div.cat')
    # print(f"category : {category.text} \n")
    for sub_menu_group in sub_menu_groups:
        sub_menu_group_name = sub_menu_group.find_element(by=By.CSS_SELECTOR, value='a.tit').text
        # print(f"sub-category: {sub_menu_group_name} ")
        sub_menu_group_items = sub_menu_group.find_elements(by=By.CSS_SELECTOR, value='a.s-itm')
        for item in sub_menu_group_items:
            link = item.get_attribute('href')
            if link and str(link).strip() != '':
                if str(item.text).strip() != '':
                    pages.append( { 'link': link, 'category':category.text, 'sub_category': sub_menu_group_name,
                                   'section': item.text.lower(),} )
                else:
                    section = link[:-1].split('/')[-1].replace("-", " ").lower()
                    pages.append( { 'link': link, 'category':category.text, 'sub_category': sub_menu_group_name,
                                   'section': section,} )
        #         print(f"section : {item.text} , {link}   ") 
        # print('')
    
print(f"Available sections : {len(pages)} \n" ) 

for page in pages:
    category_name, category_link = page['section'], page['link']
    print(f"{category_name} -- {category_link} " )
    if category_link is not None :
        last_page_scraped = False
        next_page = category_link

        while not last_page_scraped:
            # go to a page to scrape articles
            driver.get(next_page)
            close_popup(driver)
            articles_ = driver.find_elements(by=By.CSS_SELECTOR, value='article.prd._fb.col.c-prd') # get article boxes
            articles = [ ]
            for article in articles_:
                article_data = process_article(article)
                if article_data:
                    articles.append(article_data)
            data[category_name] = articles
            try:
                next_page_btn = driver.find_elements(by=By.CSS_SELECTOR, value='div.pg-w.-ptm.-pbxl a')[-2]
                if next_page_btn.accessible_name not in ['Page suivante']:
                    last_page_scraped = True
                else:
                    next_page = next_page_btn.get_attribute("href")
            except:
                last_page_scraped = True

            break # uncomment if you just want to get first page articles
        try:
            n_results_str = driver.find_element(by=By.CSS_SELECTOR, value='p.-gy5.-phs').text
        except:
            n_results_str = '0 results'
        print(f"Available articles in this category : {n_results_str.split()[0]} \n")
    
    # break # uncomment if you just want to get first category articles
# Out:
# Available sections : 252
#
# smartphones -- https://www.jumia.sn/smartphones/
# Available articles in this category : 774
#
# téléphones basics -- https://www.jumia.sn/telephones-portables/
# Available articles in this category : 169
#
# accessoires bluetooth -- https://www.jumia.sn/bluetooth/
# Available articles in this category : 103
#
# batteries téléphones -- https://www.jumia.sn/telephone-batteries/
# Available articles in this category : 51
#
# cartes microsd -- https://www.jumia.sn/telephones-tablettes-cartes-microsd/
# Available articles in this category : 18
#
# cartes mémoire -- https://www.jumia.sn/telephones-cartes-memoires/
# Available articles in this category : 14
#
# chargeurs & adaptateurs -- https://www.jumia.sn/telephonie-chargeurs-adaptateurs/
# Available articles in this category : 15
#
# chargeurs téléphones -- https://www.jumia.sn/telephone-chargeur/
# Available articles in this category : 71
#
# coques -- https://www.jumia.sn/telephones-protection/
# Available articles in this category : 129
#
# câbles -- https://www.jumia.sn/cables-et-connectiques/
# Available articles in this category : 44
#
# films et protections d'écran -- https://www.jumia.sn/telephonie-protecteurs-ecrans/
# Available articles in this category : 576
#
# montres intelligentes -- https://www.jumia.sn/montres-connectees/
# Available articles in this category : 64
#
# écouteur jack pierce -- https://www.jumia.sn/telephones-tablettes-ecouteur-jack-pierce/
# Available articles in this category : 40
#
# écouteurs bluetooth -- https://www.jumia.sn/telephones-tablettes-casques-bluetooth/
# Available articles in this category : 386
#
# accessoires tablettes -- https://www.jumia.sn/accessoires-tablettes/
# Available articles in this category : 18
#
# tablettes éducatives -- https://www.jumia.sn/tablettes-educatifs/
# Available articles in this category : 132
#
# tablettes ipad -- https://www.jumia.sn/telephones-tablettes-tablettes-ipad/
# Available articles in this category : 0
#
# téléphones fixes -- https://www.jumia.sn/telephones-fixe/
# Available articles in this category : 6
#
# samsung -- https://www.jumia.sn/telephone-tablette/samsung/
# Available articles in this category : 277
#
# infinix -- https://www.jumia.sn/telephone-tablette/infinix/
# Available articles in this category : 88
#
# huawei -- https://www.jumia.sn/telephone-tablette/huawei/
# Available articles in this category : 32
#
# apple -- https://www.jumia.sn/telephone-tablette/?q=apple
# Available articles in this category : 51
#
# tecno -- https://www.jumia.sn/telephone-tablette/tecno/
# Available articles in this category : 302
#
# haricots secs, céréales et riz -- https://www.jumia.sn/epicerie-haricots-secs-cereales-riz/
# Available articles in this category : 32
#
# pâtes, coquillages et croûtes -- https://www.jumia.sn/epicerie-pates-coquillages-croutes/
# Available articles in this category : 45
#
# céréales -- https://www.jumia.sn/epicerie-pain-boulangerie/
# Available articles in this category : 81
#
# huiles & condiments -- https://www.jumia.sn/epicerie-huiles-cuisson-vinaigres-sprays/
# Available articles in this category : 30
#
# aliments en conserve, en pot et emballés -- https://www.jumia.sn/epicerie-aliments-en-conserve-en-pot-emballes/
# Available articles in this category : 285
#
# biscuits -- https://www.jumia.sn/epicerie-bonbons-chocolat/
# Available articles in this category : 91
#
# confitures, gelées et tartinades sucrées -- https://www.jumia.sn/epicerie-confitures-gelees-tartinades-sucrees/
# Available articles in this category : 18
#
# boissons gazeuses -- https://www.jumia.sn/boissons-en-bouteille-boissons-gazeuses/
# Available articles in this category : 41
#
# café, thé & cacao -- https://www.jumia.sn/epicerie-cafe-the-cacao/
# Available articles in this category : 138
#
# jus -- https://www.jumia.sn/boissons-en-bouteille-jus/
# Available articles in this category : 149
#
# eau -- https://www.jumia.sn/boissons-en-bouteille-eau/
# Available articles in this category : 47
#
# lait et crème -- https://www.jumia.sn/lait-bebe/
# Available articles in this category : 51
#
# sirops de saveur -- https://www.jumia.sn/boissons-en-bouteille-sirops-saveur/
# Available articles in this category : 18
#
# blanchisserie -- https://www.jumia.sn/produit-lessive/
# Available articles in this category : 57
#
# articles domestiques -- https://www.jumia.sn/epicerie-articles-domestiques/
# Available articles in this category : 167
#
# vaisselle -- https://www.jumia.sn/epicerie-vaisselle/
# Available articles in this category : 11
#
# papiers hygiéniques -- https://www.jumia.sn/epicerie-papier-plastique/
# Available articles in this category : 70
#
# désodorisant -- https://www.jumia.sn/epicerie-desodorisants/
# Available articles in this category : 84
#
# outils de nettoyage -- https://www.jumia.sn/accessoires-de-nettoyage/
# Available articles in this category : 113
#
# alimentation -- https://www.jumia.sn/repas-de-bebe/
# Available articles in this category : 129
#
# bain et soin de peau -- https://www.jumia.sn/produits-bebes-bain-soin-peau/
# Available articles in this category : 151
#
# couches bébé -- https://www.jumia.sn/couches-toilettes-bebe/
# Available articles in this category : 122
#
# jouets bébé & tout-petits -- https://www.jumia.sn/jouets-bebe/
# Available articles in this category : 52
#
# sièges auto & accessoires -- https://www.jumia.sn/siege-auto-accessoires/
# Available articles in this category : 35
#
# vêtements & accessoires -- https://www.jumia.sn/produits-bebes-vetements-accessoires/
# Available articles in this category : 149
#
# maquillage -- https://www.jumia.sn/maquillage/
# Available articles in this category : 917
#
# outils & accessoires beauté -- https://www.jumia.sn/sante-beaute-outils-accessoires/
# Available articles in this category : 131
#
# soins personnels -- https://www.jumia.sn/sante-beaute-soins-personnels/
# Available articles in this category : 1921
#
# parfums de célébrités -- https://www.jumia.sn/sante-beaute-parfums-celebrites/
# Available articles in this category : 86
#
# unisexe -- https://www.jumia.sn/sante-beaute-unisexe/
# Available articles in this category : 294
#
# soins bucco-dentaires -- https://www.jumia.sn/sante-beaute-soins-bucco-dentaires/
# Available articles in this category : 171
#
# parfums -- https://www.jumia.sn/parfums/
# Available articles in this category : 906
#
# moniteurs de condition physique et d'activité -- https://www.jumia.sn/sante-beaute-moniteurs-condition-physique-activite/
# Available articles in this category : 21
#
# outils et équipement de massage -- https://www.jumia.sn/massage-relaxation/
# Available articles in this category : 169
#
# aromathérapie -- https://www.jumia.sn/sante-beaute-aromatherapie/
# Available articles in this category : 83
#
# soins & bien-être bébé -- https://www.jumia.sn/soins-bebe/
# Available articles in this category : 32
#
# santé bébé -- https://www.jumia.sn/hygiene-sante-bebe/
# Available articles in this category : 3
#
# accessoires & produits pour le bain -- https://www.jumia.sn/accessoire-de-bain/
# Available articles in this category : 45
#
# déodorants et antitranspirant -- https://www.jumia.sn/sante-beaute-deodorants-antitranspirant/
# Available articles in this category : 203
#
# rasage et épilation -- https://www.jumia.sn/rasage-epilation/
# Available articles in this category : 232
#
# soin de la peau -- https://www.jumia.sn/anti-age/
# Available articles in this category : 4463
#
# soin des cheveux -- https://www.jumia.sn/soin-cheveux/
# Available articles in this category : 1624
#
# fertilité & tests grossesse -- https://www.jumia.sn/soin-corps-pour-femme/
# Available articles in this category : 55
#
# hygiène féminine -- https://www.jumia.sn/hygiene-feminine/
# Available articles in this category : 156
#
# moniteurs de santé -- https://www.jumia.sn/appareil-de-mesure/
# Available articles in this category : 76
#
# gouttes pour les yeux, lubrifiants et lavages -- https://www.jumia.sn/sante-beaute-gouttes-yeux-lubrifiants-lavages/
# Available articles in this category : 21
#
# vitamines -- https://www.jumia.sn/vitamines-complements-alimentaires/
# Available articles in this category : 41
#
# suppléments alimentaires -- https://www.jumia.sn/sante-beaute-supplements/
# Available articles in this category : 2
#
# perte de poids -- https://www.jumia.sn/minceur-regime/
# Available articles in this category : 14
#
# protéines -- https://www.jumia.sn/sante-beaute-proteine/
# Available articles in this category : 0
#
# endurance & energie -- https://www.jumia.sn/sante-beaute-supplements/
# Available articles in this category : 2
#
# télévisions -- https://www.jumia.sn/tvs/
# Available articles in this category : 191
#
# boîtes de réception de câble -- https://www.jumia.sn/connectiques/
# Available articles in this category : 38
#
# lecteurs et enregistreurs dvd -- https://www.jumia.sn/electronique-lecteurs-enregistreurs-dvd/
# Available articles in this category : 9
#
# accessoires image & son -- https://www.jumia.sn/appareils-photos-accessoires/
# Available articles in this category : 221
#
# accessoires photo et caméscopes -- https://www.jumia.sn/photo-accessoires-divers/
# Available articles in this category : 80
#
# accessoires tv -- https://www.jumia.sn/electronique-accessoires-tv/
# Available articles in this category : 87
#
# batteries, chargeurs et accessoires -- https://www.jumia.sn/electronique-batteries-chargeurs-accessoires/
# Available articles in this category : 121
#
# caméras digitales -- https://www.jumia.sn/cameras-digitales/
# Available articles in this category : 27
#
# vidéo -- https://www.jumia.sn/videos/
# Available articles in this category : 20
#
# appareils de cuisine -- https://www.jumia.sn/petit-electromenager-cuisine/
# Available articles in this category : 564
#
# appareils de santé et de beauté -- https://www.jumia.sn/electronique-appareils-sante-beaute/
# Available articles in this category : 12
#
# luminaires & eclairage -- https://www.jumia.sn/luminaires-eclairages/
# Available articles in this category : 113
#
# nettoyeurs & aspirateurs -- https://www.jumia.sn/electronique-nettoyeurs-aspirateurs/
# Available articles in this category : 14
#
# qualité de l'air et appareils saisonniers -- https://www.jumia.sn/electronique-qualite-air-appareils-saisonniers/
# Available articles in this category : 10
#
# home cinéma -- https://www.jumia.sn/home-cinema-pour-tv/
# Available articles in this category : 65
#
# haut-parleurs -- https://www.jumia.sn/enceintes/
# Available articles in this category : 123
#
# accessoires lecteur mp3 et mp4 -- https://www.jumia.sn/accessories-radio-mp3-cd/
# Available articles in this category : 11
#
# lecteurs dvd portables -- https://www.jumia.sn/tv-lecteurs-dvd/
# Available articles in this category : 4
#
# lecteurs mp3 et ipods -- https://www.jumia.sn/lecteur-musique-portable/
# Available articles in this category : 8
#
# équipement vidéo de surveillance -- https://www.jumia.sn/electronique-equipement-video-surveillance/
# Available articles in this category : 15
#
# accessoires pour ordinateur portable -- https://www.jumia.sn/pack-et-accessoires/
# Available articles in this category : 233
#
# composants pc -- https://www.jumia.sn/equipement-informatique/
# Available articles in this category : 30
#
# imprimantes -- https://www.jumia.sn/imprimantes-pc/
# Available articles in this category : 64
#
# ordinateurs -- https://www.jumia.sn/ordinateurs-pc/
# Available articles in this category : 77
#
# scanners -- https://www.jumia.sn/scanner/
# Available articles in this category : 19
#
# solutions réseaux -- https://www.jumia.sn/reseaux-wifi/
# Available articles in this category : 136
#
# stockage de données -- https://www.jumia.sn/stockage/
# Available articles in this category : 120
#
# accessoires audio et vidéo -- https://www.jumia.sn/son-informatique/
# Available articles in this category : 60
#
# cartes mémoire -- https://www.jumia.sn/cartes-memoires/
# Available articles in this category : 32
#
# claviers & souris pc -- https://www.jumia.sn/claviers-et-souris/
# Available articles in this category : 176
#
# câbles et interconnexions -- https://www.jumia.sn/cables-connections/
# Available articles in this category : 80
#
# encre d'imprimante et toner -- https://www.jumia.sn/informatique-encre-imprimante-toner/
# Available articles in this category : 177
#
# antivirus & sécurité -- https://www.jumia.sn/informatique-antivirus-securite/
# Available articles in this category : 14
#
# bureau -- https://www.jumia.sn/informatique-bureau/
# Available articles in this category : 3
#
# appareil de cuisson -- https://www.jumia.sn/appareils-cuisson-plaques-cuisson/
# Available articles in this category : 75
#
# gazinière -- https://www.jumia.sn/appareils-cuisson-gaziniere/
# Available articles in this category : 66
#
# congélateurs -- https://www.jumia.sn/congelateurs-froid/
# Available articles in this category : 75
#
# réfrigérateurs -- https://www.jumia.sn/frigo-refrigerateurs/
# Available articles in this category : 108
#
# laveuses et sécheuses -- https://www.jumia.sn/laveuses-secheuses/
# Available articles in this category : 17
#
# préparation des boissons -- https://www.jumia.sn/petits-appareils-preparation-boissons/
# Available articles in this category : 41
#
# bouilloires -- https://www.jumia.sn/bouilloire/
# Available articles in this category : 144
#
# mélangeurs et mixeurs -- https://www.jumia.sn/petits-appareils-melange-melange/
# Available articles in this category : 164
#
# repassage et blanchisserie -- https://www.jumia.sn/petits-appareils-repassage-blanchisserie/
# Available articles in this category : 38
#
# aspirateurs -- https://www.jumia.sn/petits-appareils-aspirateurs/
# Available articles in this category : 16
#
# autres petits appareils -- https://www.jumia.sn/petits-appareils-autres-petits-appareils/
# Available articles in this category : 150
#
# art mural -- https://www.jumia.sn/maison-bureau-art-mural/
# Available articles in this category : 18
#
# articles pour événements et fêtes -- https://www.jumia.sn/articles-fetes/
# Available articles in this category : 98
#
# aspirateurs et entretien des sols -- https://www.jumia.sn/maison-bureau-aspirateurs-entretien-sols/
# Available articles in this category : 23
#
# chauffage & ventilation -- https://www.jumia.sn/climatiseur-chauffe-eau/
# Available articles in this category : 363
#
# cuisine & arts culinaires -- https://www.jumia.sn/cuisine-cuisson/
# Available articles in this category : 3943
#
# décoration de maison -- https://www.jumia.sn/maison-decoration/
# Available articles in this category : 1327
#
# fers à repasser et défroisseurs -- https://www.jumia.sn/fers-vapeur/
# Available articles in this category : 114
#
# fournitures de nettoyage -- https://www.jumia.sn/maison-bureau-fournitures-nettoyage/
# Available articles in this category : 88
#
# lampes, luminaires & plafonniers -- https://www.jumia.sn/maison-bureau-eclairage-ventilateur-plafond/
# Available articles in this category : 100
#
# literie -- https://www.jumia.sn/linge-de-lit/
# Available articles in this category : 371
#
# meubles -- https://www.jumia.sn/maison-bureau-meubles/
# Available articles in this category : 286
#
# rangements & organisation -- https://www.jumia.sn/meubles-a-tiroirs/
# Available articles in this category : 422
#
# salle de bain -- https://www.jumia.sn/maison-bureau-salle-bain/
# Available articles in this category : 213
#
# meubles -- https://www.jumia.sn/maison-meubles/
# Available articles in this category : 109
#
# literie -- https://www.jumia.sn/linge-de-maison/
# Available articles in this category : 371
#
# éclairage & luminaires -- https://www.jumia.sn/luminaire-et-eclairage/
# Available articles in this category : 56
#
# cuisines & salles de bain -- https://www.jumia.sn/maison-bureau-appareils-cuisine-salle-bain/
# Available articles in this category : 76
#
# matériaux de construction -- https://www.jumia.sn/maison-bureau-materiaux-construction/
# Available articles in this category : 23
#
# outillage à main & électroportatif -- https://www.jumia.sn/outils-de-bricolage/
# Available articles in this category : 144
#
# outils de mesure et de mise en page -- https://www.jumia.sn/outils-de-precision/
# Available articles in this category : 6
#
# peintures, outils & traitement des murs -- https://www.jumia.sn/anti-corrosion-et-autres-solutions/
# Available articles in this category : 240
#
# quincaillerie -- https://www.jumia.sn/quincaillerie-securite/
# Available articles in this category : 236
#
# électricité -- https://www.jumia.sn/bricolage-electricite/
# Available articles in this category : 337
#
# electroniques de bureau -- https://www.jumia.sn/maison-bureau-electroniques-bureau/
# Available articles in this category : 19
#
# mobilier de bureau et éclairage -- https://www.jumia.sn/mobilier-bureau/
# Available articles in this category : 42
#
# papeterie & petites fournitures -- https://www.jumia.sn/aures-equipements-de-bureau/
# Available articles in this category : 247
#
# ustencils de cuisine -- https://www.jumia.sn/cuisine-salle-manger-ustensiles-cuisine-gadgets/
# Available articles in this category : 1260
#
# petits appareils -- https://www.jumia.sn/robots-cuiseurs/
# Available articles in this category : 525
#
# diner & divertissant -- https://www.jumia.sn/cuisine-salle-manger-diner-divertissant/
# Available articles in this category : 782
#
# vaisselle -- https://www.jumia.sn/boites-de-conservation/
# Available articles in this category : 267
#
# accessoires homme -- https://www.jumia.sn/accessoires-hommes-mode/
# Available articles in this category : 603
#
# bijoux -- https://www.jumia.sn/bijoux-homme/
# Available articles in this category : 140
#
# chaussures -- https://www.jumia.sn/chaussures-hommes/
# Available articles in this category : 737
#
# costumes & accessoires -- https://www.jumia.sn/mode-homme-costumes-accessoires/
# Available articles in this category : 79
#
# montres -- https://www.jumia.sn/montres-hommes/
# Available articles in this category : 287
#
# vêtements -- https://www.jumia.sn/vetements-hommes/
# Available articles in this category : 1580
#
# vêtements traditionnels et culturels -- https://www.jumia.sn/mode-vetements-homme-traditionnels-culturels/
# Available articles in this category : 122
#
# accessoires femme -- https://www.jumia.sn/accessoires-mode-femme/
# Available articles in this category : 339
#
# bijoux -- https://www.jumia.sn/bijoux-femme/
# Available articles in this category : 1123
#
# chaussures -- https://www.jumia.sn/chaussures-femmes/
# Available articles in this category : 420
#
# costumes & accessoires -- https://www.jumia.sn/mode-costumes-accessoires/
# Available articles in this category : 30
#
# montres femmes -- https://www.jumia.sn/mode-femmes/
# Available articles in this category : 135
#
# sacs à main et portefeuilles -- https://www.jumia.sn/maroquinerie/
# Available articles in this category : 218
#
# sous-vêtements et vêtements de nuit -- https://www.jumia.sn/mode-sous-vetements-vetements-nuit/
# Available articles in this category : 281
#
# vêtements -- https://www.jumia.sn/vetements-femme/
# Available articles in this category : 1896
#
# vêtements grandes tailles -- https://www.jumia.sn/vetements-grande-taille/
# Available articles in this category : 51
#
# vêtements de maternité -- https://www.jumia.sn/grossesse-et-allaitement/
# Available articles in this category : 18
#
# vêtements traditionnels et culturels -- https://www.jumia.sn/mode-vetements-traditionnels-culturels/
# Available articles in this category : 24
#
# mode fille -- https://www.jumia.sn/mode-mode-fille/
# Available articles in this category : 17
#
# mode garçon -- https://www.jumia.sn/mode-mode-garcon/
# Available articles in this category : 6
#
# accessoires -- https://www.jumia.sn/mode-accessoires-montre/
# Available articles in this category : 55
#
# montres -- https://www.jumia.sn/montres/
# Available articles in this category : 347
#
# baignoires et sièges -- https://www.jumia.sn/produits-bebes-baignoires-sieges/
# Available articles in this category : 4
#
# bain moussant -- https://www.jumia.sn/produits-bebes-bain-moussant/
# Available articles in this category : 2
#
# ensembles cadeaux -- https://www.jumia.sn/bain-bebes-ensembles-cadeaux/
# Available articles in this category : 7
#
# sets et trousses de toilette -- https://www.jumia.sn/brosses-peignes-bebe/
# Available articles in this category : 3
#
# shampooing -- https://www.jumia.sn/produits-bebes-shampooing/
# Available articles in this category : 10
#
# soin de la peau -- https://www.jumia.sn/produits-bebes-soin-peau/
# Available articles in this category : 56
#
# savons & nettoyants -- https://www.jumia.sn/produits-bebes-savons-nettoyants/
# Available articles in this category : 59
#
# kits de bain de voyage -- https://www.jumia.sn/produits-bebes-kits-bain-voyage/
# Available articles in this category : 5
#
# boîtes de conservation -- https://www.jumia.sn/produits-bebes-stockage-alimentaire/
# Available articles in this category : 0
#
# biberons & accessoires -- https://www.jumia.sn/produits-bebes-biberon/
# Available articles in this category : 78
#
# nourriture -- https://www.jumia.sn/produits-bebes-nourriture-bebes/
# Available articles in this category : 12
#
# bébé garçon -- https://www.jumia.sn/mode-bebe-garcon/
# Available articles in this category : 50
#
# bébé fille -- https://www.jumia.sn/mode-filles-chaussures-bebes/
# Available articles in this category : 52
#
# sacs à langer -- https://www.jumia.sn/sacs-a-langer/
# Available articles in this category : 28
#
# couches jetables -- https://www.jumia.sn/couches-jetables/
# Available articles in this category : 55
#
# lingettes et accessoires -- https://www.jumia.sn/lingettes-bebe/
# Available articles in this category : 39
#
# lits & literie bébé -- https://www.jumia.sn/produits-bebes-lits-bebe-berceau/
# Available articles in this category : 43
#
# jouets de siège et poussette de voiture -- https://www.jumia.sn/produits-bebes-jouets-siege-poussette-voiture/
# Available articles in this category : 17
#
# siège auto -- https://www.jumia.sn/siege-auto-accessoires/
# Available articles in this category : 35
#
# accessoires -- https://www.jumia.sn/articles-fitness/
# Available articles in this category : 588
#
# exercice et remise en forme -- https://www.jumia.sn/exercice-remise-en-forme/
# Available articles in this category : 1270
#
# sports d'équipe -- https://www.jumia.sn/sports-d-equipe/
# Available articles in this category : 256
#
# autres sports -- https://www.jumia.sn/autres-sports/
# Available articles in this category : 1291
#
# fonctionnement -- https://www.jumia.sn/fonctionnement/
# Available articles in this category : 14
#
# tennis de table -- https://www.jumia.sn/tennis-de-table/
# Available articles in this category : 17
#
# playstation 4 -- https://www.jumia.sn/playstation-playstation-4/
# Available articles in this category : 22
#
# playstation 3 -- https://www.jumia.sn/playstation-playstation-3/
# Available articles in this category : 8
#
# playstation vita -- https://www.jumia.sn/playstation-playstation-vita/
# Available articles in this category : 0
#
# accessoires -- https://www.jumia.sn/jeux-sur-pc-accessoires/
# Available articles in this category : 13
#
# accessoires -- https://www.jumia.sn/xbox-accessoires/
# Available articles in this category : 3
#
# xbox 360 -- https://www.jumia.sn/xbox-xbox-360/
# Available articles in this category : 4
#
# xbox one -- https://www.jumia.sn/xbox-xbox-one/
# Available articles in this category : 6
#
# nintendo ds -- https://www.jumia.sn/nintendo-nintendo-ds/
# Available articles in this category : 0
#
# wii -- https://www.jumia.sn/nintendo-wii/
# Available articles in this category : 0
#
# déco exterieur -- https://www.jumia.sn/jardin-terrasse/
# Available articles in this category : 23
#
# meubles et accessoires de patio -- https://www.jumia.sn/jardin-plein-air-meubles-accessoires-patio/
# Available articles in this category : 30
#
# grillades & barbecue -- https://www.jumia.sn/jardin-plein-air-grillades-barbecue/
# Available articles in this category : 72
#
# outils électriques extérieurs -- https://www.jumia.sn/jardin-plein-air-outils-electriques-exterieurs/
# Available articles in this category : 9
#
# stockage extérieurs -- https://www.jumia.sn/fauteuils-et-chaises-d-exterieur/
# Available articles in this category : 1
#
# gels lavants -- https://www.jumia.sn/catalog/?q=gel+lavant
# Available articles in this category : 13
#
# protection -- https://www.jumia.sn/epicerie-nettoyage-domestique/
# Available articles in this category : 199
#
# savons -- https://www.jumia.sn/catalog/?q=savon
# Available articles in this category : 1087
#
# alimentation -- https://www.jumia.sn/epicerie/
# Available articles in this category : 2354
#
# carrefour sénégal -- https://www.jumia.sn/mlp-boutique-officielle-carrefoursenegal/
# Available articles in this category : 7
#
# osanis -- https://www.jumia.sn/mlp-boutique-officielle-osanis/
# Available articles in this category : 0
#
# soboa -- https://www.jumia.sn/sp-boutique-officielle-soboa/
# Available articles in this category : 0
#
# kirene -- https://www.jumia.sn/boutique-officielle-kirene/?source=sn_flyout
# Available articles in this category : 0
#
# topicrem -- https://www.jumia.sn/mlp-boutique-officielle-topicrem/
# Available articles in this category : 34
#
# darling -- https://www.jumia.sn/mlp-boutique-officielle-darling/
# Available articles in this category : 10
#
# françoise bedon -- https://www.jumia.sn/mlp-boutique-officielle-pr-francoise-bedon/
# Available articles in this category : 0
#
# tijinou -- https://www.jumia.sn/tijinou/
# Available articles in this category : 34
#
# nivea -- https://www.jumia.sn/mlp-boutique-officielle-nivea/
# Available articles in this category : 3
#
# bic senegal -- https://www.jumia.sn/boutique-bic/?source=sn_flyout
# Available articles in this category : 0
#
# nasco -- https://www.jumia.sn/mlp-boutique-officielle-nasco/
# Available articles in this category : 0
#
# huawei -- https://www.jumia.sn/mlp-boutique-officielle-huawei/
# Available articles in this category : 0
#
# infinix -- https://www.jumia.sn/boutique-officielle-infinix/
# Available articles in this category : 0
#
# joya -- https://www.jumia.sn/boutique-officielle-joya/
# Available articles in this category : 0
#
# nutrimental -- https://www.jumia.sn/nutrimental/?tag=JMALL&source=sn_flyout
# Available articles in this category : 0
#
# candes -- https://www.jumia.sn/boutique-officielle-candes/
# Available articles in this category : 0
#
# gb foods -- https://www.jumia.sn/mlp-boutique-officielle-gb-foods/
# Available articles in this category : 0
#
# royal shop negoce -- https://www.jumia.sn/mlp-boutique-officielle-royal-shop-negoce/
# Available articles in this category : 14
#
# mlp boutique officielle samsung -- https://www.jumia.sn/mlp-boutique-officielle-samsung/
# Available articles in this category : 40
#
# ?tag=jmall&source=sn_flyou -- https://www.jumia.sn/pampers/?tag=JMALL&source=sn_flyout
# Available articles in this category : 11
#
# mlp boutique officielle tecno -- https://www.jumia.sn/mlp-boutique-officielle-tecno/
# Available articles in this category : 71
#
# mlp boutique officielle dano -- https://www.jumia.sn/mlp-boutique-officielle-dano/
# Available articles in this category : 9
#
# mlp boutique officielle linguere -- https://www.jumia.sn/mlp-boutique-officielle-linguere/
# Available articles in this category : 0
#
# mlp boutique officielle smiley -- https://www.jumia.sn/mlp-boutique-officielle-smiley/
# Available articles in this category : 1
#
# boutique officielle nuhanciam -- https://www.jumia.sn/boutique-officielle-nuhanciam/
# Available articles in this category : 0
#
# boutique officielle lux -- https://www.jumia.sn/boutique-officielle-lux/
# Available articles in this category : 0
#
# mlp boutique officielle casanova -- https://www.jumia.sn/mlp-boutique-officielle-casanova/
# Available articles in this category : 0
#
# vetements femme -- https://www.jumia.sn/vetements-femme/
# Available articles in this category : 1896
#
# chaussures femmes -- https://www.jumia.sn/chaussures-femmes/
# Available articles in this category : 420
#
# accessoires mode femme -- https://www.jumia.sn/accessoires-mode-femme/
# Available articles in this category : 339
#
# vetements hommes -- https://www.jumia.sn/vetements-hommes/
# Available articles in this category : 1580
#
# chaussures hommes -- https://www.jumia.sn/chaussures-hommes/
# Available articles in this category : 737
#
# accessoires hommes mode -- https://www.jumia.sn/accessoires-hommes-mode/
# Available articles in this category : 603
#
# grandes tailles bas -- https://www.jumia.sn/grandes-tailles-bas/
# Available articles in this category : 7434
#
# maison cuisine jardin -- https://www.jumia.sn/maison-cuisine-jardin/
# Available articles in this category : 10536
#
# cuisine cuisson -- https://www.jumia.sn/cuisine-cuisson/
# Available articles in this category : 3943
#
# bricolage et jardinage -- https://www.jumia.sn/bricolage-et-jardinage/
# Available articles in this category : 1339
#
# climatiseur chauffe eau -- https://www.jumia.sn/climatiseur-chauffe-eau/
# Available articles in this category : 363

# %%
data
# Out:
# {'smartphones': [{'name': 'Samsung Galaxy A03 Core - 4G - 6.5" - RAM 2Go - ROM 32Go - Caméra 13+2MP - 5000mAh- Noir',
#    'price': '48 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a03-core-4g-6.5-ram-2go-rom-32go-camera-132mp-5000mah-noir-6100199.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/99/10016/1.jpg?8517',
#    'jumia_express': True,
#    'old_price': '75 000 FCFA',
#    'decrease_percentage': '35%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(56)'},
#   {'name': 'Samsung Galaxy A03 Core - 4G - 6.5" - RAM 2Go - ROM 32Go - Caméra 13+2MP - 5000mAh- Bleu',
#    'price': '48 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a03-core-4g-6.5-ram-2go-rom-32go-camera-132mp-5000mah-bleu-9845388.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/88/35489/1.jpg?6701',
#    'jumia_express': True,
#    'old_price': '75 000 FCFA',
#    'decrease_percentage': '35%',
#    'n_stars': '3.9 out of 5',
#    'n_votes': '(34)'},
#   {'name': 'Tecno POP 2F - 5.5’’ - Double SIM - ROM 16 Go - RAM 1 Go - Caméra 8/5 Mp - Batterie : 2400mAh - Noir',
#    'price': '32 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-2f-5.5-double-sim-rom-16-go-ram-1-go-camera-85-mp-batterie-2400mah-noir-5977478.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/87/47795/1.jpg?5803',
#    'jumia_express': True,
#    'old_price': '47 970 FCFA',
#    'decrease_percentage': '31%',
#    'n_stars': '3.7 out of 5',
#    'n_votes': '(64)'},
#   {'name': 'Tecno Spark 8P- 6.6" - ROM 64Go - RAM 4Go - Caméra 50MP/8MP - 5000mAh - Tahiti Gold',
#    'price': '73 550 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-spark-8p-6.6-rom-64go-ram-4go-camera-50mp8mp-5000mah-tahiti-gold-9790229.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/92/20979/1.jpg?6263',
#    'jumia_express': True,
#    'old_price': '95 000 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '4.7 out of 5',
#    'n_votes': '(19)'},
#   {'name': 'Tecno Pova Neo- Ecran 6.8" - ROM 64Go - RAM 4Go - Caméra13MP/8MP Dual flash Batterie 6000mAh - Bleu',
#    'price': '60 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pova-neo-ecran-6.8-rom-64go-ram-4go-camera13mp8mp-dual-flash-batterie-6000mah-bleu-9844854.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/45/84489/1.jpg?0177',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '39%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Tecno POP 5 Go - 3G - Ecran 5.71" - ROM 16Go Ram 1Go - Caméra front 5MP arrière 5MP - Batterie 4000mAh - Bleu',
#    'price': '35 750 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-5-go-3g-ecran-5.71-rom-16go-ram-1go-camera-front-5mp-arriere-5mp-batterie-4000mah-bleu-9844336.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/34489/1.jpg?2473',
#    'jumia_express': True,
#    'old_price': '50 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Samsung Galaxy A12 – Ecran 6.5″ - ROM 128GB - RAM 4GB - Caméra 48MP - Bleu',
#    'price': '87 700 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a12-ecran-6.5-rom-128gb-ram-4gb-camera-48mp-bleu-10001120.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/110001/1.jpg?4777',
#    'jumia_express': True,
#    'old_price': '95 000 FCFA',
#    'decrease_percentage': '8%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Tecno Spark 8C – Écran 6.6″ – ROM 64GB – RAM 2GB – Caméra 13/8MP – Gris',
#    'price': '63 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-spark-8c-ecran-6.6-rom-64gb-ram-2gb-camera-138mp-gris-9979136.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/19799/1.jpg?8434',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '36%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(7)'},
#   {'name': 'Samsung Galaxy A03S - 4G - 6.5" - RAM 4Go - ROM 64Go - Caméra 13+2+2MP - Empreinte digitale',
#    'price': '74 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a03s-4g-6.5-ram-4go-rom-64go-camera-1322mp-empreinte-digitale-9795740.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/04/75979/1.jpg?0977',
#    'jumia_express': True,
#    'old_price': '80 000 FCFA',
#    'decrease_percentage': '7%',
#    'n_stars': '4.5 out of 5',
#    'n_votes': '(13)'},
#   {'name': 'Samsung Galaxy A13 - 6.6" - RAM 4Go - ROM 64Go - Caméra 50+5+2+2MP - 5000mAh – Black',
#    'price': '96 960 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a13-6.6-ram-4go-rom-64go-camera-50522mp-5000mah-black-9961272.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/27/21699/1.jpg?6949',
#    'jumia_express': True,
#    'old_price': '104 900 FCFA',
#    'decrease_percentage': '8%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Apple IPhone X - 4G LTE - 5.8 Pouces - 3Go Ram - 64Go Rom - 12 Mpx - Blanc - Reconditionné',
#    'price': '169 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/apple-iphone-x-4g-lte-5.8-pouces-3go-ram-64go-rom-12-mpx-blanc-reconditionne-9842231.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/13/22489/1.jpg?8232',
#    'jumia_express': True,
#    'old_price': '229 000 FCFA',
#    'decrease_percentage': '26%',
#    'n_stars': '4.8 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Infinix Smart HD 2021 - 3G - 6,1" HD - Rom 32Go - Ram 2Go - Caméra 8MP Camera front 8MP - 5000mAh - Noir',
#    'price': '45 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/infinix-smart-hd-2021-3g-61-hd-rom-32go-ram-2go-camera-8mp-camera-front-8mp-5000mah-noir-6482125.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/52/12846/1.jpg?3376',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '54%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(59)'},
#   {'name': 'Tecno Spark 8C – Écran 6.6″ – ROM 64GB – RAM 2GB – Caméra 13/8MP – Noir',
#    'price': '63 750 FCFA',
#    'descrption_link': 'https://www.jumia.sn/spark-8c-ecran-6.6-rom-64gb-ram-2gb-camera-138mp-noir-tecno-mpg46405.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/76299/1.jpg?6263',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '36%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(9)'},
#   {'name': 'Tecno Spark 8C – Écran 6.6″ – ROM 64GB – RAM 3GB – Caméra 13/8MP – Cyan',
#    'price': '69 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-spark-8c-ecran-6.6-rom-64gb-ram-3gb-camera-138mp-cyan-9944351.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/15/34499/1.jpg?2475',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(6)'},
#   {'name': 'Tecno Camon 18i - 6.55" -ROM 128Go- RAM 4Go -Camera 48MP / 8 MP- 5000mAh - Space Grey',
#    'price': '90 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/camon-18i-ecran-6.55-rom-128go-ram-4go-camera-arriere-48mp-front-8-mp-5000mah-space-grey-tecno-mpg43599.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/71379/1.jpg?1754',
#    'jumia_express': True,
#    'old_price': '120 000 FCFA',
#    'decrease_percentage': '24%',
#    'n_stars': '3.7 out of 5',
#    'n_votes': '(25)'},
#   {'name': 'Infinix Smart HD 2021 - 3G - 6,1" HD - Rom 32Go - Ram 2Go - Caméra 8MP Camera front 8MP - 5000mAh - Bleu',
#    'price': '45 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/infinix-smart-hd-2021-3g-61-hd-rom-32go-ram-2go-camera-8mp-camera-front-8mp-5000mah-bleu-9844332.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/23/34489/1.jpg?2474',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '54%',
#    'n_stars': '3.9 out of 5',
#    'n_votes': '(9)'},
#   {'name': 'Samsung Galaxy A12 – Ecran 6.5″ - ROM 128GB - RAM 4GB - Caméra 48MP - Noir',
#    'price': '87 700 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a12-ecran-6.5-rom-128gb-ram-4gb-camera-48mp-noir-10001119.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/91/110001/1.jpg?4777',
#    'jumia_express': True,
#    'old_price': '95 000 FCFA',
#    'decrease_percentage': '8%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Samsung Galaxy A12 - 4G - 6.5" - RAM 4Go - ROM 64Go - Caméra 48+5+2+2MP - 5000mAh – Bleu',
#    'price': '100 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/galaxy-a12-4g-6.5-ram-4go-rom-64go-camera-48522mp-5000mah-bleu-samsung-mpg37592.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/75/73529/1.jpg?7890',
#    'jumia_express': False,
#    'old_price': '',
#    'decrease_percentage': '',
#    'n_stars': '4.4 out of 5',
#    'n_votes': '(108)'},
#   {'name': 'Samsung Galaxy A03 - 4G - 6.5" - 3Go - 32Go - 48Mpx - 5000 MAh - Bleu',
#    'price': '59 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a03-4g-6.5-3go-32go-48mpx-5000-mah-bleu-9961292.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/29/21699/1.jpg?9074',
#    'jumia_express': True,
#    'old_price': '69 900 FCFA',
#    'decrease_percentage': '14%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Mione I12 - 5.99" - RAM 1Go - ROM 8Go - Caméra 5MP - Batterie 2800mAh - Gold',
#    'price': '23 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-i12-5.99-ram-1go-rom-8go-camera-5mp-batterie-2800mah-gold-9900872.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/27/80099/1.jpg?5211',
#    'jumia_express': True,
#    'old_price': '29 900 FCFA',
#    'decrease_percentage': '20%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Tecno Pop 5P – Écran 6.52″ – Pop 5 P - ROM 32GB – RAM 2GB – Caméra 8/5MP – Noir',
#    'price': '50 050 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-5p-ecran-6.52-pop-5-p-rom-32gb-ram-2gb-camera-85mp-noir-9221020.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/01229/1.jpg?4300',
#    'jumia_express': True,
#    'old_price': '65 000 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(27)'},
#   {'name': 'Tecno Camon 17 - 6.55" - 128Go - RAM 6Go - Ultra triple Camera arrière 48MP - Front 16MP - 5000mAh - Deep Sea',
#    'price': '99 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-camon-17-6.55-128go-ram-6go-ultra-triple-camera-arriere-48mp-front-16mp-5000mah-deep-sea-8817331.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/13/37188/1.jpg?3379',
#    'jumia_express': True,
#    'old_price': '127 270 FCFA',
#    'decrease_percentage': '22%',
#    'n_stars': '4.3 out of 5',
#    'n_votes': '(36)'},
#   {'name': 'Tecno Pop 5 – Écran 6.1″ – ROM 32GB – RAM 2GB – Caméra 5/5MP - 5000 mAh - Bleu',
#    'price': '46 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-5-ecran-6.1-rom-32gb-ram-2gb-camera-55mp-5000-mah-bleu-9791712.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/21/71979/1.jpg?2474',
#    'jumia_express': True,
#    'old_price': '60 000 FCFA',
#    'decrease_percentage': '22%',
#    'n_stars': '3.6 out of 5',
#    'n_votes': '(13)'},
#   {'name': 'Tecno Spark 8P- 6.6" - ROM 64Go - RAM 4Go - Caméra 50MP / 8MP - 5000mAh - Cyan',
#    'price': '73 550 FCFA',
#    'descrption_link': 'https://www.jumia.sn/spark-8-p-6.6-rom-64go-ram-4go-camera-50mp-8mp-5000mah-cyan-tecno-mpg45006.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/03/20979/1.jpg?0179',
#    'jumia_express': True,
#    'old_price': '95 000 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '4.5 out of 5',
#    'n_votes': '(16)'},
#   {'name': 'Tecno POP 5 Go - 3G - 5.71" - ROM 16Go - RAM 1Go - Caméra 5MP / 5MP - 4000mAh - Noir',
#    'price': '35 750 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-5-go-3g-5.71-rom-16go-ram-1go-camera-5mp-5mp-4000mah-noir-9844334.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/43/34489/1.jpg?4663',
#    'jumia_express': True,
#    'old_price': '50 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno Spark 8C – Écran 6.6″ – ROM 64GB – RAM 2GB – Caméra 13/8MP – Purple',
#    'price': '63 750 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-spark-8c-ecran-6.6-rom-64gb-ram-2gb-camera-138mp-purple-9944344.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/44/34499/1.jpg?0085',
#    'jumia_express': True,
#    'old_price': '100 000 FCFA',
#    'decrease_percentage': '36%',
#    'n_stars': '4.4 out of 5',
#    'n_votes': '(5)'},
#   {'name': 'Infinix Smart 5 3G- 6,6" HD - Rom 32Go - Ram 2Go - Caméra 8MP Camera front 8MP - 5000mAh - Ocean Wave',
#    'price': '49 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/smart-5-3g-66-hd-rom-32go-ram-2go-camera-8mp-camera-front-8mp-5000mah-ocean-wave-infinix-mpg36592.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/43/12846/1.jpg?4645',
#    'jumia_express': True,
#    'old_price': '67 000 FCFA',
#    'decrease_percentage': '26%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Tecno Pop 5 – Écran 6.1″ – ROM 16GB – RAM 1GB – Caméra 5/5MP – 4000 mAh - Noir',
#    'price': '42 600 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-pop-5-ecran-6.1-rom-16gb-ram-1gb-camera-55mp-4000-mah-noir-9221021.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/12/01229/1.jpg?2052',
#    'jumia_express': True,
#    'old_price': '60 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(12)'},
#   {'name': 'Infinix Smart 5 4G - 6,6" HD - Rom 32Go - Ram 2Go - Caméra 8MP - 5000mAh - Noir',
#    'price': '53 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/infinix-smart-5-4g-66-hd-rom-32go-ram-2go-camera-8mp-5000mah-noir-6482115.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/51/12846/1.jpg?4645',
#    'jumia_express': True,
#    'old_price': '67 000 FCFA',
#    'decrease_percentage': '20%',
#    'n_stars': '3.9 out of 5',
#    'n_votes': '(31)'},
#   {'name': 'Samsung Galaxy A13 - 6.6" - RAM 4Go - ROM 128Go - Caméra 50+5+2+2MP - 5000mAh – Black',
#    'price': '107 270 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a13-6.6-ram-4go-rom-128go-camera-50522mp-5000mah-black-9961273.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/21699/1.jpg?3889',
#    'jumia_express': True,
#    'old_price': '114 900 FCFA',
#    'decrease_percentage': '7%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Samsung Galaxy A13 - Ecran 6.6" - RAM 4Go - ROM 64Go - Bleu clair',
#    'price': '96 960 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a13-ecran-6.6-ram-4go-rom-64go-bleu-clair-10002688.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/88/620001/1.jpg?3888',
#    'jumia_express': True,
#    'old_price': '104 900 FCFA',
#    'decrease_percentage': '8%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno Camon 18i - 6.55" -ROM 128Go- RAM 4Go -Camera 48MP / 8 MP - 5000mAh - Jewel bleu',
#    'price': '90 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-camon-18i-6.55-rom-128go-ram-4go-camera-48mp-8-mp-5000mah-jewel-bleu-9732536.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/52379/1.jpg?6735',
#    'jumia_express': True,
#    'old_price': '120 000 FCFA',
#    'decrease_percentage': '24%',
#    'n_stars': '4.2 out of 5',
#    'n_votes': '(11)'},
#   {'name': 'Samsung Galaxy A03 - 4G - 6.5" - 3Go - 32Go - 48Mpx - 5000 MAh - Noir',
#    'price': '60 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a03-4g-6.5-3go-32go-48mpx-5000-mah-noir-9961294.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/49/21699/1.jpg?9076',
#    'jumia_express': True,
#    'old_price': '69 900 FCFA',
#    'decrease_percentage': '13%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Tecno Camon 17 P- Ecran 6.8" - ROM 128Go - RAM 6Go -Camera 64MP - Batterie 5000mAh - Vert',
#    'price': '110 300 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-camon-17-p-ecran-6.8-rom-128go-ram-6go-camera-64mp-batterie-5000mah-vert-9100326.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/62/30019/1.jpg?9130',
#    'jumia_express': True,
#    'old_price': '190 000 FCFA',
#    'decrease_percentage': '42%',
#    'n_stars': '4.2 out of 5',
#    'n_votes': '(14)'},
#   {'name': 'Samsung Galaxy A22- Ecran 6.6" - ROM 128Go RAM 4Go - Noir',
#    'price': '113 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a22-ecran-6.6-rom-128go-ram-4go-noir-10002686.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/620001/1.jpg?3880',
#    'jumia_express': True,
#    'old_price': '159 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Samsung Galaxy A13 - Ecran 6.6" - RAM 4Go - ROM 128Go - Bleu clair',
#    'price': '107 270 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-galaxy-a13-ecran-6.6-ram-4go-rom-128go-bleu-clair-10002687.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/78/620001/1.jpg?3884',
#    'jumia_express': True,
#    'old_price': '114 900 FCFA',
#    'decrease_percentage': '7%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Apple IPhone 13 Pro - 6.1 - 128 Go - 12 Mpx - 12 Mpx - 5G - Gold',
#    'price': '685 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/apple-iphone-13-pro-6.1-128-go-12-mpx-12-mpx-5g-gold-9846941.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/14/96489/1.jpg?2820',
#    'jumia_express': True,
#    'old_price': '755 000 FCFA',
#    'decrease_percentage': '9%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Apple iPhone 7 Plus - 5.5" - 4G - 3/128Go - 12Mpx - Reconditionné - Gold',
#    'price': '139 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/apple-iphone-7-plus-5.5-4g-3128go-12mpx-reconditionne-gold-9698758.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/85/78969/1.jpg?7818',
#    'jumia_express': True,
#    'old_price': '189 900 FCFA',
#    'decrease_percentage': '27%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Mione Q12 - Ecran 5.5" - RAM 2Go - ROM 8Go - Caméra 5/ 2Mpx - Batterie 2800mAh - Noir',
#    'price': '23 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-q12-ecran-5.5-ram-2go-rom-8go-camera-5-2mpx-batterie-2800mah-noir-9971051.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/15/01799/1.jpg?7226',
#    'jumia_express': True,
#    'old_price': '28 900 FCFA',
#    'decrease_percentage': '19%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Oking Mate 20 PRO - Ecran 6.1" Ips - ROM 16Go Ram 2Go- Caméra 5 / 5MP - Batterie 2800 mAh',
#    'price': '27 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mate-20-pro-ecran-6.1-ips-rom-16go-ram-2go-camera-5-5mp-batterie-2800-mah-oking-mpg37098.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/80/92595/1.jpg?5768',
#    'jumia_express': False,
#    'old_price': '50 000 FCFA',
#    'decrease_percentage': '46%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(26)'}],
#  'telephones portables': [{'name': 'Mione AB1 -Écran1.44" - RAM 32 Mo - ROM 32 Mo - Dual Sim - Batterie 800 mAh - Noir/Rouge',
#    'price': '3 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-ab1-ecran1.44-ram-32-mo-rom-32-mo-dual-sim-batterie-800-mah-noirrouge-10003095.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/59/030001/1.jpg?5211',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '61%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Mione F6 -Écran1.77" - RAM 64 Mo - ROM 32 Mo - Dual Sim - Batterie 10000 mAh - Noir',
#    'price': '4 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-f6-ecran1.77-ram-64-mo-rom-32-mo-dual-sim-batterie-10000-mah-noir-10003104.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/40/130001/1.jpg?7228',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '51%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T101-Écran1.77" - RAM 32 Mo - ROM 32 Mo - Dual Sim - Batterie 1000 mAh - Noir',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t101-ecran1.77-ram-32-mo-rom-32-mo-dual-sim-batterie-1000-mah-noir-8841036.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/01488/1.jpg?3376',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '41%',
#    'n_stars': '3.8 out of 5',
#    'n_votes': '(96)'},
#   {'name': 'Tecno T402 - 3 SIM - ROM 8MB - RAM 8MB - 1500 mAh - 2.4"- Gold',
#    'price': '8 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t402-3-sim-rom-8mb-ram-8mb-1500-mah-2.4-gold-8837573.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/57388/1.jpg?0558',
#    'jumia_express': True,
#    'old_price': '20 000 FCFA',
#    'decrease_percentage': '58%',
#    'n_stars': '4.4 out of 5',
#    'n_votes': '(26)'},
#   {'name': 'Tecno T101- Écran 1.77" - RAM 32 Mo - ROM 32 Mo - Dual Sim - 1000 mAh - Bleu',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t101-ecran-1.77-ram-32-mo-rom-32-mo-dual-sim-1000-mah-bleu-8849871.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/89488/1.jpg?7064',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '41%',
#    'n_stars': '3.8 out of 5',
#    'n_votes': '(38)'},
#   {'name': 'Tecno T301- Écran 1.77" - RAM 4 Mo - ROM 4 Mo - Dual Sim - Batterie 1150 mAh - Noir',
#    'price': '7 670 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t301-ecran-1.77-ram-4-mo-rom-4-mo-dual-sim-batterie-1150-mah-noir-8837575.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/57/57388/1.jpg?0558',
#    'jumia_express': True,
#    'old_price': '',
#    'decrease_percentage': '',
#    'n_stars': '3.9 out of 5',
#    'n_votes': '(20)'},
#   {'name': 'Oking OK - 28mini - Ecran 1,7" - Double SIM - Battarie : 3000mAh - FM Radio - Double Torche - 12 Mois Garantie',
#    'price': '8 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/ok-28mini-ecran-17-double-sim-battarie-3000mah-fm-radio-double-torche-12-mois-garantie-oking-mpg14562.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/50/78192/1.jpg?6026',
#    'jumia_express': False,
#    'old_price': '9 500 FCFA',
#    'decrease_percentage': '6%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(13)'},
#   {'name': 'Nokia - 105 - 1.8" - Dual SIM - FM Radio Lamp Torch - 1020mAh - Noir',
#    'price': '9 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/nokia-105-1.8-dual-sim-fm-radio-lamp-torch-1020mah-noir-9974264.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/46/24799/1.jpg?8271',
#    'jumia_express': False,
#    'old_price': '12 500 FCFA',
#    'decrease_percentage': '24%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T528 - Écran 130 x 57 x 14.5mm " - 16 Mo ROM + 8 Mo RAM - Dual Sim - Batterie 2500 mAh - Gris',
#    'price': '11 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t528-ecran-130-x-57-x-14.5mm-16-mo-rom-8-mo-ram-dual-sim-batterie-2500-mah-gris-8849872.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/27/89488/1.jpg?4008',
#    'jumia_express': True,
#    'old_price': '16 770 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '4.3 out of 5',
#    'n_votes': '(6)'},
#   {'name': 'Mione F6 -Écran1.77" - RAM 64 Mo - ROM 32 Mo - Dual Sim - Batterie 1000 mAh - Rouge',
#    'price': '4 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-f6-ecran1.77-ram-64-mo-rom-32-mo-dual-sim-batterie-1000-mah-rouge-10003097.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/79/030001/1.jpg?0436',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '51%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Nokia - 150 - 2.4" - 5MP - FM Radio - Lampe Torche - BT - 1020 mAh',
#    'price': '16 800 FCFA',
#    'descrption_link': 'https://www.jumia.sn/nokia-150-2.4-5mp-fm-radio-lampe-torche-bt-1020-mah-10000199.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/99/100001/1.jpg?0955',
#    'jumia_express': False,
#    'old_price': '19 000 FCFA',
#    'decrease_percentage': '12%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Oking OK699 - Ecran 1,7" - Double SIM - Battarie : 2500 mAh - FM Radio - Super Lamp Torche',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/oking-ok699-ecran-17-double-sim-battarie-2500-mah-fm-radio-super-lamp-torche-10028896.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/69/882001/1.jpg?2501',
#    'jumia_express': False,
#    'old_price': '6 900 FCFA',
#    'decrease_percentage': '14%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Samsung B310 - Dual Sim - Ecran 1.45" - Radio Fm - 800 mAh - Bleu',
#    'price': '14 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/b310-dual-sim-ecran-1.45-radio-fm-800-mah-bleu-samsung-mpg37512.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/83/769/1.jpg?6105',
#    'jumia_express': False,
#    'old_price': '20 000 FCFA',
#    'decrease_percentage': '28%',
#    'n_stars': '4.3 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Tecno T660 - 2.4" - RAM 16Mo - ROM 8Mo - FM Radio Lamp Torch - BT - 1100mAh - Silver',
#    'price': '10 550 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t660-2.4-ram-16mo-rom-8mo-fm-radio-lamp-torch-bt-1100mah-silver-8837570.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/07/57388/1.jpg?2779',
#    'jumia_express': True,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '4.5 out of 5',
#    'n_votes': '(15)'},
#   {'name': 'Tecno T467- Écran 2.4" - RAM 4 Mo - ROM 4 Mo - Triple Sim - 2500 mAh - Noir',
#    'price': '10 025 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t467-ecran-2.4-ram-4-mo-rom-4-mo-triple-sim-2500-mah-noir-9838283.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/38/28389/1.jpg?5214',
#    'jumia_express': True,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '33%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Tecno T529 - Écran 139*59*14.1mm - 16 Mb ROM + 8 Mb RAM - Dual Sim - Batterie 2500 mAh - Gold',
#    'price': '11 600 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t529-ecran-1395914.1mm-16-mb-rom-8-mb-ram-dual-sim-batterie-2500-mah-gold-9838289.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/98/28389/1.jpg?5802',
#    'jumia_express': True,
#    'old_price': '16 770 FCFA',
#    'decrease_percentage': '31%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T529 - Écran 139*59*14.1mm - 16 Mb ROM + 8 Mb RAM - Dual Sim - Batterie 2500 mAh - violet',
#    'price': '11 600 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t529-ecran-1395914.1mm-16-mb-rom-8-mb-ram-dual-sim-batterie-2500-mah-violet-9838287.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/78/28389/1.jpg?4007',
#    'jumia_express': True,
#    'old_price': '16 770 FCFA',
#    'decrease_percentage': '31%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Nokia 105 dual Sim',
#    'price': '10 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/105-dual-sim-black-nokia-mpg37068.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/60/11339/1.jpg?1972',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(6)'},
#   {'name': 'Tecno T352- Écran 1.77" - RAM 4 Mo - ROM 4 Mo - Dual Sim - Facebook préinstallé - Batterie 2500 mAh - Noir',
#    'price': '7 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t352-ecran-1.77-ram-4-mo-rom-4-mo-dual-sim-facebook-preinstalle-batterie-2500-mah-noir-9838279.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/97/28389/1.jpg?5802',
#    'jumia_express': True,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '47%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Tecno T454- Écran 2.8" - RAM 4 Mo - ROM 4 Mo - Dual Sim - Facebook préinstallé - Batterie 1500 mAh - Noir',
#    'price': '9 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t454-ecran-2.8-ram-4-mo-rom-4-mo-dual-sim-facebook-preinstalle-batterie-1500-mah-noir-9838280.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/08/28389/1.jpg?5802',
#    'jumia_express': True,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '34%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Samsung B310 - Dual Sim - Ecran 1.45" - Radio Fm - 800 mAh - Blanc',
#    'price': '14 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/b310-dual-sim-ecran-1.45-radio-fm-800-mah-blanc-samsung-mpg44996.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/78/51489/1.jpg?2492',
#    'jumia_express': False,
#    'old_price': '20 000 FCFA',
#    'decrease_percentage': '28%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Tecno T301- Écran 1.7" - RAM 4 Mo - ROM 4 Mo - Dual Sim - Batterie 1150 mAh - Doré',
#    'price': '6 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t301-ecran-1.7-ram-4-mo-rom-4-mo-dual-sim-batterie-1150-mah-dore-8837574.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/47/57388/1.jpg?4007',
#    'jumia_express': True,
#    'old_price': '7 080 FCFA',
#    'decrease_percentage': '3%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Itel It 5081 - 2.4" - 3 SIM - Batterie : 1200mAh - FM Radio - Lamp Torch - Ultra Mince',
#    'price': '8 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/itel-it-5081-2.4-3-sim-batterie-1200mah-fm-radio-lamp-torch-ultra-mince-4012671.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/62104/1.jpg?6276',
#    'jumia_express': False,
#    'old_price': '18 000 FCFA',
#    'decrease_percentage': '51%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Tecno T528 - Écran 130 x 57 x 14.5mm " - 16 Mo ROM + 8 Mo RAM - Dual Sim - Batterie 2500 mAh - Gold',
#    'price': '12 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t528-ecran-130-x-57-x-14.5mm-16-mo-rom-8-mo-ram-dual-sim-batterie-2500-mah-gold-8849882.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/28/89488/1.jpg?4011',
#    'jumia_express': True,
#    'old_price': '16 770 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '1 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Itel IT 5081 - Triple Sim - 64MB ROM - 64MB RAM 1200mAh -',
#    'price': '9 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/it-5081-triple-sim-4mb-rom-4mb-ram-1000mah-bleu-itel-mpg36693.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/23/279/1.jpg?5164',
#    'jumia_express': False,
#    'old_price': '17 900 FCFA',
#    'decrease_percentage': '47%',
#    'n_stars': '4.8 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Itel It 2160 - Dual SIM, 1.77 Pouces - 1.3 Mégapixels - 4 MB RAM - 4 MB Rom- 1000mAh - FM - Lampe Torche - Noir',
#    'price': '6 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/itel-it2160-dual-sim-1.77-pouces-1.3-megapixels-4-mb-ram-4-mb-rom-battery-1000mah-fm-lampe-torche-noir-itel-mpg3100.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/91/41121/1.jpg?3787',
#    'jumia_express': False,
#    'old_price': '9 000 FCFA',
#    'decrease_percentage': '28%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(12)'},
#   {'name': 'Samsung E1205 Keystone 2 - 1 sim - Noir',
#    'price': '11 900 FCFA - 13 990 FCFA',
#    'descrption_link': 'https://www.jumia.sn/e1205-keystone-2-1-sim-noir-samsung-mpg37539.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/30/6374/1.jpg?6415',
#    'jumia_express': False,
#    'old_price': '',
#    'decrease_percentage': '',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Nokia - 210 - 2.4" - Dual SIM - 0.3Mp - FM Radio Lamp Torch - 1020mAh - Noir',
#    'price': '19 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/nokia-210-2.4-dual-sim-0.3mp-fm-radio-lamp-torch-1020mah-noir-9927224.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/42/27299/1.jpg?2459',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '20%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T402 - 3 SIM - ROM: 8MB - RAM: 8MB - 1500 mAh - 2.4"- Noir',
#    'price': '9 050 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t402-3-sim-rom-8mb-ram-8mb-1500-mah-2.4-noir-8837572.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/27/57388/1.jpg?4007',
#    'jumia_express': True,
#    'old_price': '11 050 FCFA',
#    'decrease_percentage': '18%',
#    'n_stars': '3.2 out of 5',
#    'n_votes': '(13)'},
#   {'name': 'Q10 - Ecran 2,8" - Double SIM - Ultra Slim - BT Call - Battarie : 1300 mAh - FM Radio - Super Lamp Torche - Dore',
#    'price': '17 300 FCFA',
#    'descrption_link': 'https://www.jumia.sn/x-tigi-q10-ecran-28-double-sim-ultra-slim-bt-call-battarie-1300-mah-fm-radio-super-lamp-torche-dore-5935285.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/58/25395/1.jpg?5270',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '31%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Samhe S5703 - Dual SIM - 1.77" - FM Radio Lamp Torch - BT - 2500 mAh',
#    'price': '6 700 FCFA',
#    'descrption_link': 'https://www.jumia.sn/s5703-dual-sim-1.77-fm-radio-lamp-torch-bt-2500-mah-samhe-mpg44995.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/51489/1.jpg?2491',
#    'jumia_express': False,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '33%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Samsung E1205 - 1.52" -1 SIM- FM Radio - 800mAh - Noir',
#    'price': '11 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-e1205-1.52-1-sim-fm-radio-800mah-noir-9970671.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/60799/1.jpg?1997',
#    'jumia_express': False,
#    'old_price': '14 900 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Nokia 3310 Series 30 - Ecran : 2.4" QVGA - Résolution de 320 x 240 pixelsr 167 ppi RAM : 16 Mo APN : 2 MP avec flash Led -Bleu',
#    'price': '24 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/nokia-3310-series-30-ecran-2.4-qvga-resolution-de-320-x-240-pixelsr-167-ppi-ram-16-mo-apn-2-mp-avec-flash-led-bleu-98534.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/43/589/1.jpg?6884',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Nokia 5310 - 2.4" - Dual SIM - 16Mo - FM Radio Lamp Torch - BT - 1200mAh - Noir',
#    'price': '24 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/nokia-5310-2.4-dual-sim-16mo-fm-radio-lamp-torch-bt-1200mah-noir-9828564.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/46/58289/1.jpg?6846',
#    'jumia_express': False,
#    'old_price': '27 000 FCFA',
#    'decrease_percentage': '8%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T372 - 3 Sim - Ecran 2,4 Pouces - FM Radio - Lamp Torch - Batterie 1150mAh',
#    'price': '12 200 FCFA',
#    'descrption_link': 'https://www.jumia.sn/t372-3-sim-ecran-24-pouces-fm-radio-lamp-torch-batterie-1150mah-tecno-mpg38150.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/10183/1.jpg?4972',
#    'jumia_express': False,
#    'old_price': '14 500 FCFA',
#    'decrease_percentage': '16%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Q3 - Ecran 1.44" - RAM 32Mo - ROM 32Mo - Caméra 0.08MP - 900mAh',
#    'price': '13 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/x-tigi-q3-ecran-1.44-ram-32mo-rom-32mo-camera-0.08mp-900mah-6131903.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/30/91316/1.jpg?3173',
#    'jumia_express': False,
#    'old_price': '17 000 FCFA',
#    'decrease_percentage': '21%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Nokia 105 - Dual Sim - Ecran 1,8 Pouces - Rom 4 Mo, Lampe Torche - FM Radio -',
#    'price': '10 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/105-dual-sim-ecran-18-pouces-rom-4-mo-lampe-torche-fm-radio-bleu-nokia-mpg12360.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/88/91139/1.jpg?0320',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '3.4 out of 5',
#    'n_votes': '(12)'},
#   {'name': 'Samsung GT- E1207T - Dual SIM - 1. 52 " - Batterie Li-Ion 800 mAh - Radio FM - Lumière flash -',
#    'price': '13 900 FCFA - 13 999 FCFA',
#    'descrption_link': 'https://www.jumia.sn/samsung-gt-e1207t-dual-sim-1.-52-batterie-li-ion-800-mah-radio-fm-lumiere-flash-473601.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/10/6374/1.jpg?6058',
#    'jumia_express': False,
#    'old_price': '',
#    'decrease_percentage': '',
#    'n_stars': '1 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Mione AB4 -Écran1.77" - RAM 32 Mo - ROM 32 Mo - Dual Sim - Batterie 2500 mAh - Noir/rouge',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mione-ab4-ecran1.77-ram-32-mo-rom-32-mo-dual-sim-batterie-2500-mah-noirrouge-10003098.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/89/030001/1.jpg?0436',
#    'jumia_express': True,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '41%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Tecno T301- Écran 1.77" - RAM 4 Mo - ROM 4 Mo - Dual Sim - Batterie 1150 mAh -',
#    'price': '6 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tecno-t301-ecran-1.77-ram-4-mo-rom-4-mo-dual-sim-batterie-1150-mah-9832847.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/82389/1.jpg?0220',
#    'jumia_express': False,
#    'old_price': '9 900 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '',
#    'n_votes': ''}],
#  'bluetooth': [{'name': 'Generic Oreillettes sans fil p47 pour casque Bluetooth',
#    'price': '3 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/oreillettes-sans-fil-p47-pour-casque-bluetooth-generic-mpg34696.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/96016/1.jpg?2046',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '77%',
#    'n_stars': '3.9 out of 5',
#    'n_votes': '(23)'},
#   {'name': 'Generic Casque Audio Sans Fil Bleutooth multicolore',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/casque-audio-sans-fil-bleutooth-multicolore-generic-mpg32862.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/75/70835/1.jpg?2865',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '76%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(68)'},
#   {'name': 'Generic Premium Casque P47sans fil pour casque Bluetooth',
#    'price': '3 700 FCFA',
#    'descrption_link': 'https://www.jumia.sn/premium-casque-p47sans-fil-pour-casque-bluetooth-generic-mpg34970.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/21/12729/1.jpg?0909',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '75%',
#    'n_stars': '3.4 out of 5',
#    'n_votes': '(69)'},
#   {'name': 'Generic Ecouteur Bluetooth sans fil pour tout smartphone',
#    'price': '12 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ecouteur-bluetooth-sans-fil-pour-tout-smartphone-9962855.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/55/82699/1.jpg?9942',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '66%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Generic Ecouteur Audio Sans Fil Bleutooth magnétique noir',
#    'price': '4 190 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ecouteur-audio-sans-fil-bleutooth-magnetique-noir-9849808.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/80/89489/1.jpg?0741',
#    'jumia_express': False,
#    'old_price': '10 000 FCFA',
#    'decrease_percentage': '58%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(2)'},
#   {'name': 'Generic Écouteurs Bluetooth Pro5 - Noir',
#    'price': '4 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/ecouteurs-bluetooth-pro5-noir-generic-mpg36272.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/09/52099/1.jpg?8703',
#    'jumia_express': False,
#    'old_price': '12 000 FCFA',
#    'decrease_percentage': '63%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(28)'},
#   {'name': 'Lighting Adaptateur USB-C to Headphone Jack',
#    'price': '1 470 FCFA',
#    'descrption_link': 'https://www.jumia.sn/lighting-adaptateur-usb-c-to-headphone-jack-10002797.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/79/720001/1.jpg?1600',
#    'jumia_express': False,
#    'old_price': '7 000 FCFA',
#    'decrease_percentage': '79%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'White Label Casque P47 sans fil avec Bluetooth connecté',
#    'price': '4 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/casque-p47-sans-fil-avec-bluetooth-connecte-white-label-mpg43921.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/59/80389/1.jpg?5524',
#    'jumia_express': False,
#    'old_price': '8 000 FCFA',
#    'decrease_percentage': '50%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Generic Casque Audio Sans Fil Bleutooth 24h autonomie qualité garantie B',
#    'price': '5 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/casque-audio-sans-fil-bleutooth-24h-autonomie-qualite-garantie-b-generic-mpg45316.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/33/30589/1.jpg?9676',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '61%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Casque sans fil Bluetooth avec luminosité réglable de 7 couleurs',
#    'price': '8 800 FCFA',
#    'descrption_link': 'https://www.jumia.sn/casque-sans-fil-bluetooth-avec-luminosite-reglable-de-7-couleurs-generic-mpg44916.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/52/30589/1.jpg?9676',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '75%',
#    'n_stars': '3.3 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Generic Casque p47sans fil pour casque Bluetooth',
#    'price': '3 300 FCFA',
#    'descrption_link': 'https://www.jumia.sn/casque-p47sans-fil-pour-casque-bluetooth-generic-mpg32867.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/41/71629/1.jpg?2310',
#    'jumia_express': False,
#    'old_price': '12 000 FCFA',
#    'decrease_percentage': '73%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(31)'},
#   {'name': 'Generic Écouteurs Pro 5 Bleutooth qualité garantie',
#    'price': '8 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/ecouteurs-pro-5-bleutooth-qualite-garantie-generic-mpg45706.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/93/31379/1.jpg?9191',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '66%',
#    'n_stars': '3.6 out of 5',
#    'n_votes': '(5)'},
#   {'name': 'Generic Casque F sans fil Bluetooth avec luminosité réglable de 7 couleurs',
#    'price': '8 800 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-casque-f-sans-fil-bluetooth-avec-luminosite-reglable-de-7-couleurs-9926530.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/03/56299/1.jpg?1058',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '65%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Ecouteur pro 10 sans fil Bluetooth extra puissant',
#    'price': '9 800 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ecouteur-pro-10-sans-fil-bluetooth-extra-puissant-9788349.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/94/38879/1.jpg?4765',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '61%',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Generic 3D Casque P47 sans fil Stéréo Bluetooth - Noir',
#    'price': '4 275 FCFA',
#    'descrption_link': 'https://www.jumia.sn/3d-casque-p47-sans-fil-stereo-bluetooth-noir-generic-mpg43839.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/71/58639/1.jpg?3024',
#    'jumia_express': False,
#    'old_price': '7 000 FCFA',
#    'decrease_percentage': '39%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Generic Premium Casque P47 + EDR - Version 2022 - Bleu',
#    'price': '3 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-premium-casque-p47-edr-version-2022-bleu-9842992.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/29/92489/1.jpg?4132',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '77%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Casque sans fil Bluetooth multicolore BL',
#    'price': '5 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-casque-sans-fil-bluetooth-multicolore-bl-9414727.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/72/74149/1.jpg?6920',
#    'jumia_express': False,
#    'old_price': '18 000 FCFA',
#    'decrease_percentage': '69%',
#    'n_stars': '5 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Bluetooth Wireless Ecouteurs Intra-Auriculaires Bluetooth S109',
#    'price': '2 450 FCFA',
#    'descrption_link': 'https://www.jumia.sn/wireless-ecouteurs-intra-auriculaires-bluetooth-s109-bluetooth-mpg46426.html',
# ...
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/43/04535/1.jpg?3471',
#    'jumia_express': False,
#    'old_price': '12 000 FCFA',
#    'decrease_percentage': '71%',
#    'n_stars': '1 out of 5',
#    'n_votes': '(1)'},
#   {'name': 'Roch Split 1.5 CV Anti-corrosion Et Anti-bactérie -12000BTU - R410 - RAC-S09R4-A - Blanc',
#    'price': '161 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/roch-split-1.5-cv-anti-corrosion-et-anti-bacterie-12000btu-r410-rac-s09r4-a-blanc-8816356.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/65/36188/1.jpg?1646',
#    'jumia_express': True,
#    'old_price': '220 000 FCFA',
#    'decrease_percentage': '27%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(8)'},
#   {'name': 'White Label Ventilateur Sur Pied 10″ – Ventilateur Sur Pied - 10 Pouces – Noir',
#    'price': '9 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/white-label-ventilateur-sur-pied-10-ventilateur-sur-pied-10-pouces-noir-10022244.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/44/222001/1.jpg?6162',
#    'jumia_express': False,
#    'old_price': '11 000 FCFA',
#    'decrease_percentage': '14%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'TenGO Ventilateur Climatiseur à Eau - Blanc',
#    'price': '62 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/ventilateur-climatiseur-a-eau-blanc-tengo-mpg38157.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/62/00809/1.jpg?0832',
#    'jumia_express': False,
#    'old_price': '110 000 FCFA',
#    'decrease_percentage': '44%',
#    'n_stars': '3.2 out of 5',
#    'n_votes': '(16)'},
#   {'name': 'Global Air Ventilateur Sur Pied - 65W - Noir',
#    'price': '19 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/global-air-ventilateur-sur-pied-65w-noir-214558.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/85/5412/1.jpg?3274',
#    'jumia_express': True,
#    'old_price': '28 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '3.7 out of 5',
#    'n_votes': '(6)'},
#   {'name': 'White Label Ventilateur Sur Pied 10″ – Ventilateur Sur Pied - 10 Pouces – Noir',
#    'price': '9 999 FCFA',
#    'descrption_link': 'https://www.jumia.sn/white-label-ventilateur-sur-pied-10-ventilateur-sur-pied-10-pouces-noir-9998346.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/64/38999/1.jpg?3071',
#    'jumia_express': False,
#    'old_price': '19 500 FCFA',
#    'decrease_percentage': '49%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'White Label MINI VENTILATEUR PORTATIF RECHARGEABLES PAR USB -BLANC',
#    'price': '3 150 FCFA',
#    'descrption_link': 'https://www.jumia.sn/mini-ventilateur-portatif-rechargeables-par-usb-blanc-white-label-mpg40533.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/60/17159/1.jpg?5308',
#    'jumia_express': False,
#    'old_price': '4 500 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '3.7 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Global Air Ventilateur Sur Pied - 16 pouces - Gris',
#    'price': '19 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/global-air-ventilateur-sur-pied-16-pouces-gris-1213818.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/81/83121/1.jpg?5449',
#    'jumia_express': True,
#    'old_price': '22 680 FCFA',
#    'decrease_percentage': '12%',
#    'n_stars': '4.1 out of 5',
#    'n_votes': '(9)'},
#   {'name': 'Evernal Pack de 2 Ventilateurs Mural - 16" oscillation à 90 degrés -sans télécommande',
#    'price': '29 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/pack-de-2-ventilateurs-mural-16-oscillation-a-90-degres-sans-telecommande-evernal-mpg43834.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/20/60149/1.jpg?1120',
#    'jumia_express': False,
#    'old_price': '45 000 FCFA',
#    'decrease_percentage': '34%',
#    'n_stars': '4.3 out of 5',
#    'n_votes': '(3)'},
#   {'name': 'Generic Ventilateur de sol télescopique rechargeable & ajustable avec câble de charge',
#    'price': '12 600 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ventilateur-de-sol-telescopique-rechargeable-ajustable-avec-cable-de-charge-10022238.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/83/222001/1.jpg?6162',
#    'jumia_express': False,
#    'old_price': '18 000 FCFA',
#    'decrease_percentage': '30%',
#    'n_stars': '4.5 out of 5',
#    'n_votes': '(2)'},
#   {'name': "Artic White Mini climatiseur, refroidisseur d'air humidificateur M201 vert",
#    'price': '14 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/artic-white-mini-climatiseur-refroidisseur-dair-humidificateur-m201-vert-9402180.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/08/12049/1.jpg?4600',
#    'jumia_express': False,
#    'old_price': '',
#    'decrease_percentage': '',
#    'n_stars': '3.5 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Evernal Ventilateur Sur Pied " - Télécommande - Blanc',
#    'price': '17 670 FCFA',
#    'descrption_link': 'https://www.jumia.sn/evernal-ventilateur-sur-pied-telecommande-blanc-10029038.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/83/092001/1.jpg?8813',
#    'jumia_express': False,
#    'old_price': '38 000 FCFA',
#    'decrease_percentage': '54%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': "Generic Deshumidificateur Absorbeur D'humidité - 500 ml - rose",
#    'price': '2 200 FCFA',
#    'descrption_link': 'https://www.jumia.sn/deshumidificateur-absorbeur-dhumidite-500-ml-rose-generic-mpg33149.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/03/29639/1.jpg?9393',
#    'jumia_express': False,
#    'old_price': '4 500 FCFA',
#    'decrease_percentage': '51%',
#    'n_stars': '3.8 out of 5',
#    'n_votes': '(34)'},
#   {'name': 'Evernal Ventilateur Sur Pied " - Télécommande - Blanc',
#    'price': '19 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/evernal-ventilateur-sur-pied-telecommande-blanc-475038.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/83/0574/1.jpg?1769',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '46%',
#    'n_stars': '4.5 out of 5',
#    'n_votes': '(10)'},
#   {'name': "Artic White Refroidisseur D'air - Mini Climatiseur Humidificateur - Blanc",
#    'price': '13 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/artic-white-refroidisseur-dair-mini-climatiseur-humidificateur-blanc-10022256.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/65/222001/1.jpg?6164',
#    'jumia_express': False,
#    'old_price': '30 000 FCFA',
#    'decrease_percentage': '57%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Global Air Pack de 2 Ventilateur Sur Pied 10pouces hauteur 90cm - Noir',
#    'price': '16 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/global-air-pack-de-2-ventilateur-sur-pied-10pouces-hauteur-90cm-noir-10028959.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/95/982001/1.jpg?7711',
#    'jumia_express': True,
#    'old_price': '20 000 FCFA',
#    'decrease_percentage': '18%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Global Air Pack 2 Ventilateur Mural 16" - Oscillation 90° - 3 Réglages de Vitesse-+ Télécommande',
#    'price': '38 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/global-air-pack-2-ventilateur-mural-16-oscillation-90-3-reglages-de-vitesse-telecommande-41023.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/32/014/1.jpg?9912',
#    'jumia_express': True,
#    'old_price': '43 900 FCFA',
#    'decrease_percentage': '11%',
#    'n_stars': '4.3 out of 5',
#    'n_votes': '(85)'},
#   {'name': 'White Label Pack de 2 Ventilateurs Sur Pied Blanc',
#    'price': '21 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/white-label-pack-de-2-ventilateurs-sur-pied-blanc-561840.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/04/8165/1.jpg?9471',
#    'jumia_express': False,
#    'old_price': '38 000 FCFA',
#    'decrease_percentage': '42%',
#    'n_stars': '4.2 out of 5',
#    'n_votes': '(12)'},
#   {'name': "Generic Deshumidificateur Absorbeur D'humidité - 500 ml - vanille",
#    'price': '2 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/deshumidificateur-absorbeur-dhumidite-500-ml-vanille-generic-mpg33150.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/13/29639/1.jpg?9393',
#    'jumia_express': False,
#    'old_price': '45 000 FCFA',
#    'decrease_percentage': '94%',
#    'n_stars': '4 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'White Label Ventilateur Mural 3 Réglages de Vitesse, Inclinaison Réglable avec Télécommande',
#    'price': '27 600 FCFA',
#    'descrption_link': 'https://www.jumia.sn/white-label-ventilateur-mural-3-reglages-de-vitesse-inclinaison-reglable-avec-telecommande-9998342.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/24/38999/1.jpg?3070',
#    'jumia_express': False,
#    'old_price': '50 000 FCFA',
#    'decrease_percentage': '45%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Thomson Split Climatiseur Thomson 9000 BTU - Blanc',
#    'price': '153 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/thomson-split-climatiseur-thomson-9000-btu-blanc-9970879.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/97/80799/1.jpg?2437',
#    'jumia_express': True,
#    'old_price': '170 000 FCFA',
#    'decrease_percentage': '9%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Chouette Et Utile Mini Ventilateur Silencieux / Rechargeable - Blanc',
#    'price': '28 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/chouette-et-utile-mini-ventilateur-silencieux-rechargeable-blanc-9970720.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/70799/1.jpg?1010',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '20%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Ventilateur de sol télescopique rechargeable & ajustable avec câble de charge',
#    'price': '8 700 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ventilateur-de-sol-telescopique-rechargeable-ajustable-avec-cable-de-charge-9372594.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/49/52739/1.jpg?4556',
#    'jumia_express': False,
#    'old_price': '15 000 FCFA',
#    'decrease_percentage': '42%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Roch Chauffe-Eau Electrique - 50 Litres - RWH-50V15 - Blanc',
#    'price': '65 490 FCFA',
#    'descrption_link': 'https://www.jumia.sn/roch-chauffe-eau-electrique-50-litres-rwh-50v15-blanc-10000750.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/700001/1.jpg?3931',
#    'jumia_express': True,
#    'old_price': '75 000 FCFA',
#    'decrease_percentage': '13%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'TCL Climatiseur Split - TCL - 1.25CV - 9000 BTU - Blanc - Garantie 12 Mois',
#    'price': '190 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/tcl-climatiseur-split-tcl-1.25cv-9000-btu-blanc-garantie-12-mois-106703.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/30/7601/1.jpg?0225',
#    'jumia_express': False,
#    'old_price': '230 000 FCFA',
#    'decrease_percentage': '17%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Ventilateur Changli Crown12 Box Fan KYT-30A - Gris',
#    'price': '16 990 FCFA',
#    'descrption_link': 'https://www.jumia.sn/ventilateur-changli-crown12-box-fan-kyt-30a-gris-generic-mpg35998.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/33/69083/1.jpg?4970',
#    'jumia_express': False,
#    'old_price': '35 000 FCFA',
#    'decrease_percentage': '51%',
#    'n_stars': '4.6 out of 5',
#    'n_votes': '(5)'},
#   {'name': 'Sharp Climatiseur Split - 1.25 CV - 9000 BTU - Blanc - Gaz-410- Garantie 6 Mois',
#    'price': '169 900 FCFA',
#    'descrption_link': 'https://www.jumia.sn/sharp-climatiseur-split-1.25-cv-9000-btu-blanc-gaz-410-garantie-6-mois-71817.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/71/817/1.jpg?1779',
#    'jumia_express': True,
#    'old_price': '190 000 FCFA',
#    'decrease_percentage': '11%',
#    'n_stars': '3.8 out of 5',
#    'n_votes': '(11)'},
#   {'name': 'White Label Ventilateur Sur Pied EVERNAL',
#    'price': '27 500 FCFA',
#    'descrption_link': 'https://www.jumia.sn/white-label-ventilateur-sur-pied-evernal-9998347.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/38999/1.jpg?3071',
#    'jumia_express': False,
#    'old_price': '39 000 FCFA',
#    'decrease_percentage': '29%',
#    'n_stars': '1 out of 5',
#    'n_votes': '(1)'},
#   {'name': "Binatone Refroidisseur d'air - Binatone - BAC 201 - 85W - 20 Litres - Noir",
#    'price': '89 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/binatone-refroidisseur-dair-binatone-bac-201-85w-20-litres-noir-9990449.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/94/40999/1.jpg?2338',
#    'jumia_express': False,
#    'old_price': '115 000 FCFA',
#    'decrease_percentage': '23%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'LG - Climatiseur Split Inverter - 1.25 CV - 9000 BTU - Blanc - Garantie 12 Mois',
#    'price': '310 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/lg-climatiseur-split-inverter-1.25-cv-9000-btu-blanc-garantie-12-mois-106698.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/89/6601/1.jpg?0225',
#    'jumia_express': False,
#    'old_price': '350 000 FCFA',
#    'decrease_percentage': '11%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Generic Ventilateur Climatiseur à Eau Air Cooler 67litres',
#    'price': '158 999 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-ventilateur-climatiseur-a-eau-air-cooler-67litres-10029045.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/54/092001/1.jpg?8818',
#    'jumia_express': False,
#    'old_price': '250 000 FCFA',
#    'decrease_percentage': '36%',
#    'n_stars': '',
#    'n_votes': ''},
#   {'name': 'Pack de 2 Ventilateur Sur Pied 12 pouces hauteur 90cm - Noir',
#    'price': '20 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/oceanic-pack-de-2-ventilateur-sur-pied-12-pouces-hauteur-90cm-noir-3958815.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/51/88593/1.jpg?9527',
#    'jumia_express': False,
#    'old_price': '22 500 FCFA',
#    'decrease_percentage': '11%',
#    'n_stars': '3.6 out of 5',
#    'n_votes': '(8)'},
#   {'name': 'Generic Mini Air Cooler Ventilateur de Refroidissement à Eau Portable',
#    'price': '12 990 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-mini-air-cooler-ventilateur-de-refroidissement-a-eau-portable-9160560.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/50619/1.jpg?6085',
#    'jumia_express': False,
#    'old_price': '18 000 FCFA',
#    'decrease_percentage': '28%',
#    'n_stars': '3 out of 5',
#    'n_votes': '(4)'},
#   {'name': 'Generic Refroidisseur espace personnel',
#    'price': '15 000 FCFA',
#    'descrption_link': 'https://www.jumia.sn/generic-refroidisseur-espace-personnel-10008047.html',
#    'img_link': 'https://sn.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/74/080001/1.jpg?6264',
#    'jumia_express': False,
#    'old_price': '25 000 FCFA',
#    'decrease_percentage': '40%',
#    'n_stars': '1 out of 5',
#    'n_votes': '(1)'}]}

# %%
import os
list_of_dfs = []
for section, articles in data.items():
    df = pd.DataFrame(articles)
    df.to_csv( os.path.join( "data", f"section {section}.csv"), index=False  )
    
    df['section'] = section
    list_of_dfs.append(df)
    

global_df = pd.concat( list_of_dfs, axis=0)
global_df.to_csv( os.path.join( "data", f"GLOBAL_SECTION.csv"), index=False  )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1348/1623893474.py in <module>
#       3 for section, articles in data.items():
#       4     df = pd.DataFrame(articles)
# ----> 5     df.to_csv( os.path.join( "data", f"section {section}.csv"), index=False  )
#       6
#       7     df['section'] = section
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# OSError: [Errno 22] Invalid argument: 'data\\section ?tag=jmall&source=sn_flyou.csv'
